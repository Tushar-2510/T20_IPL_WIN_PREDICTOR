# %% [markdown]
# ## Predicting chasing team winning probability

# %% [markdown]
# # Problem Statement
# ### Make a win predictor that displays the probability of the chasing team winning an IPL match after every over.
# ## Dataset:- https://www.kaggle.com/datasets/ramjidoolla/ipl-data-set

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read the data

# %%
match_df= pd.read_csv("./ipl_data/matches.csv")

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
match_df.shape
# Out:
# (756, 18)

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
match_df.shape
# Out:
# (756, 18)

# %% [markdown]
# ## Reading the 2nd file since no run rate, total score etc

# %%
deliveries_df= pd.read_csv("./ipl_data/deliveries.csv")

# %%
deliveries_df.head(10)
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
#
#    ball    batsman non_striker       bowler  is_super_over  ...  bye_runs  \
# ...

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# ## Total scores in every match

# %%
deliveries_df.groupby(['match_id','inning']).sum()['total_runs']
# Groupby groups the data according to the match id and innings and summing the total for the individual groups
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
inning_score=deliveries_df.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
#reset index sets the index and makes the variable dataframe since there is different columns created 
inning_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
#we need only 1st innings score
inning_score = inning_score[inning_score["inning"]==1]
inning_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %% [markdown]
# ## Merge the match_df with inn_scores dataframe on id

# %%
match_df =match_df.merge(inning_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
 match_df['total_runs']+=1

# %%
match_df.rename(columns={'total_runs':'target'},inplace=True)

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## Clean up the dataframe
# ### Deccan chargers and srh are same + delhi daredavils and delhi capitals

# %%
match_df['team1']=match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df['team1']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2']=match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Rising Pune Supergiants'], dtype=object)

# %% [markdown]
# ## Keeping data for only existing teams

# %%
teams = [
    'Chennai Super Kings',
    'Delhi Capitals',
    'Mumbai Indians',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Rajasthan Royals',
    'Royal Challengers Bangalore',
    'Sunrisers Hyderabad'
]
#using isin method to retain only the teams in this row

# %%
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 6   7  IPL-2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8  IPL-2017     Indore  10-04-2017  Royal Challengers Bangalore
# 9  10  IPL-2017     Mumbai  12-04-2017          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4               Delhi Capitals  Royal Challengers Bangalore           bat
# 6               Mumbai Indians               Mumbai Indians         field
# 7              Kings XI Punjab  Royal Challengers Bangalore           bat
# 9               Mumbai Indians               Mumbai Indians         field
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
type(match_df['team1'])
# Out:
# pandas.core.series.Series

# %%
match_df.shape
# Out:
# (641, 20)

# %%
deliveries_df.shape
# Out:
# (179078, 21)

# %% [markdown]
# ## Getting rid of DL method

# %%
match_df = match_df[match_df['dl_applied']==0]

# %%
match_df['dl_applied'].unique()
# Out:
# array([0], dtype=int64)

# %% [markdown]
# ## Now to only keep the relevant columns

# %%
match_df=match_df[['match_id','city','winner','target']]
match_df.head()
# Out:
#    match_id       city                       winner  target
# 0         1  Hyderabad          Sunrisers Hyderabad     208
# 4         5  Bangalore  Royal Challengers Bangalore     158
# 6         7     Mumbai               Mumbai Indians     179
# 7         8     Indore              Kings XI Punjab     149
# 9        10     Mumbai               Mumbai Indians     159

# %%
match_df.shape
# Out:
# (626, 4)

# %% [markdown]
# ## Match status(crr,rrr, runs left,etc) of 2nd innings

# %%
deliveries_df=match_df.merge(deliveries_df,on='match_id')

# %%
deliveries_df=deliveries_df[deliveries_df['inning']==2]
deliveries_df
# Out:
#         match_id       city               winner  target  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad     208       2
# 126            1  Hyderabad  Sunrisers Hyderabad     208       2
# 127            1  Hyderabad  Sunrisers Hyderabad     208       2
# 128            1  Hyderabad  Sunrisers Hyderabad     208       2
# 129            1  Hyderabad  Sunrisers Hyderabad     208       2
# ...          ...        ...                  ...     ...     ...
# 149573     11415  Hyderabad       Mumbai Indians     153       2
# 149574     11415  Hyderabad       Mumbai Indians     153       2
# 149575     11415  Hyderabad       Mumbai Indians     153       2
# 149576     11415  Hyderabad       Mumbai Indians     153       2
# 149577     11415  Hyderabad       Mumbai Indians     153       2
#
#                        batting_team         bowling_team  over  ball  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %% [markdown]
# ## calculating current score

# %%
deliveries_df['current_score']=deliveries_df.groupby('match_id').cumsum()['total_runs']

# %%
deliveries_df
# Out:
#         match_id       city               winner  target  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad     208       2
# 126            1  Hyderabad  Sunrisers Hyderabad     208       2
# 127            1  Hyderabad  Sunrisers Hyderabad     208       2
# 128            1  Hyderabad  Sunrisers Hyderabad     208       2
# 129            1  Hyderabad  Sunrisers Hyderabad     208       2
# ...          ...        ...                  ...     ...     ...
# 149573     11415  Hyderabad       Mumbai Indians     153       2
# 149574     11415  Hyderabad       Mumbai Indians     153       2
# 149575     11415  Hyderabad       Mumbai Indians     153       2
# 149576     11415  Hyderabad       Mumbai Indians     153       2
# 149577     11415  Hyderabad       Mumbai Indians     153       2
#
#                        batting_team         bowling_team  over  ball  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
deliveries_df['runs_left']=deliveries_df['target']-deliveries_df['current_score']

# %%
deliveries_df
# Out:
#         match_id       city               winner  target  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad     208       2
# 126            1  Hyderabad  Sunrisers Hyderabad     208       2
# 127            1  Hyderabad  Sunrisers Hyderabad     208       2
# 128            1  Hyderabad  Sunrisers Hyderabad     208       2
# 129            1  Hyderabad  Sunrisers Hyderabad     208       2
# ...          ...        ...                  ...     ...     ...
# 149573     11415  Hyderabad       Mumbai Indians     153       2
# 149574     11415  Hyderabad       Mumbai Indians     153       2
# 149575     11415  Hyderabad       Mumbai Indians     153       2
# 149576     11415  Hyderabad       Mumbai Indians     153       2
# 149577     11415  Hyderabad       Mumbai Indians     153       2
#
#                        batting_team         bowling_team  over  ball  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %%
deliveries_df['balls_left']=120-((deliveries_df['over']-1)*6+deliveries_df['ball'])

# %% [markdown]
# ## Wickets

# %%
deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].fillna(0)
deliveries_df['player_dismissed']=deliveries_df['player_dismissed'].apply(lambda x:x if x==0 else 1)
deliveries_df.tail()
# Out:
#         match_id       city          winner  target  inning  \
# 149573     11415  Hyderabad  Mumbai Indians     153       2
# 149574     11415  Hyderabad  Mumbai Indians     153       2
# 149575     11415  Hyderabad  Mumbai Indians     153       2
# 149576     11415  Hyderabad  Mumbai Indians     153       2
# 149577     11415  Hyderabad  Mumbai Indians     153       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        penalty_runs batsman_runs  extra_runs  total_runs  player_dismissed  \
# 149573            0            1           0           1                 0
# ...

# %%
deliveries_df['wickets_left']=10-deliveries_df.groupby('match_id').cumsum()['player_dismissed']
deliveries_df.tail()
# Out:
#         match_id       city          winner  target  inning  \
# 149573     11415  Hyderabad  Mumbai Indians     153       2
# 149574     11415  Hyderabad  Mumbai Indians     153       2
# 149575     11415  Hyderabad  Mumbai Indians     153       2
# 149576     11415  Hyderabad  Mumbai Indians     153       2
# 149577     11415  Hyderabad  Mumbai Indians     153       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 149573  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 149574  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 149575  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 149576  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 149577  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        batsman_runs extra_runs  total_runs  player_dismissed  dismissal_kind  \
# 149573            1          0           1                 0             NaN
# ...

# %%
deliveries_df['crr']=deliveries_df['current_score']*6/(120-deliveries_df['balls_left'])
deliveries_df['rrr']=deliveries_df['runs_left']*6/deliveries_df['balls_left']
#crr=current run rate

# %%
deliveries_df
# Out:
#         match_id       city               winner  target  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad     208       2
# 126            1  Hyderabad  Sunrisers Hyderabad     208       2
# 127            1  Hyderabad  Sunrisers Hyderabad     208       2
# 128            1  Hyderabad  Sunrisers Hyderabad     208       2
# 129            1  Hyderabad  Sunrisers Hyderabad     208       2
# ...          ...        ...                  ...     ...     ...
# 149573     11415  Hyderabad       Mumbai Indians     153       2
# 149574     11415  Hyderabad       Mumbai Indians     153       2
# 149575     11415  Hyderabad       Mumbai Indians     153       2
# 149576     11415  Hyderabad       Mumbai Indians     153       2
# 149577     11415  Hyderabad       Mumbai Indians     153       2
#
#                        batting_team         bowling_team  over  ball  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %% [markdown]
# ## Team batting 2nd win or lose 0 or 1

# %%
def matchresult(df):
    return 1 if df['batting_team']==df['winner'] else 0

# %%
deliveries_df['result']=deliveries_df.apply(matchresult,axis=1)
# axis =1 the function is applied row wise

# %%
deliveries_df
# Out:
#         match_id       city               winner  target  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad     208       2
# 126            1  Hyderabad  Sunrisers Hyderabad     208       2
# 127            1  Hyderabad  Sunrisers Hyderabad     208       2
# 128            1  Hyderabad  Sunrisers Hyderabad     208       2
# 129            1  Hyderabad  Sunrisers Hyderabad     208       2
# ...          ...        ...                  ...     ...     ...
# 149573     11415  Hyderabad       Mumbai Indians     153       2
# 149574     11415  Hyderabad       Mumbai Indians     153       2
# 149575     11415  Hyderabad       Mumbai Indians     153       2
# 149576     11415  Hyderabad       Mumbai Indians     153       2
# 149577     11415  Hyderabad       Mumbai Indians     153       2
#
#                        batting_team         bowling_team  over  ball  \
# 125     Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# ...

# %% [markdown]
# ## Removing useless columns from final df

# %%
final_df=deliveries_df[['batting_team','bowling_team','city','target','crr','rrr','wickets_left','balls_left','runs_left','result']]

# %%
final_df.head()
# Out:
#                     batting_team         bowling_team       city  target  crr  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad     208  6.0
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad     208  3.0
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad     208  2.0
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad     208  4.5
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad     208  8.4
#
#            rrr  wickets_left  balls_left  runs_left  result
# 125  10.436975            10         119        207       0
# 126  10.525424            10         118        207       0
# 127  10.615385            10         117        207       0
# 128  10.603448            10         116        205       0
# 129  10.486957            10         115        201       0

# %%
final_df.shape
# Out:
# (71342, 10)

# %%
#dropping nan data
final_df.dropna(inplace=True)

# %%
#Not use of the situation when rrr becomes inf
final_df = final_df[final_df['balls_left'] != 0]

# %% [markdown]
# ## Feature Selection

# %%
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]

# %% [markdown]
# ## Train Test Split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,random_state=1)
#random_state=1 to get same train and test data about every reload

# %%
X_train
# Out:
#                        batting_team                 bowling_team  \
# 22755              Rajasthan Royals              Kings XI Punjab
# 149502          Chennai Super Kings               Mumbai Indians
# 4619                 Mumbai Indians  Royal Challengers Bangalore
# 90058         Kolkata Knight Riders              Kings XI Punjab
# 135658        Kolkata Knight Riders          Sunrisers Hyderabad
# ...                             ...                          ...
# 103573             Rajasthan Royals          Sunrisers Hyderabad
# 43015               Deccan Chargers  Royal Challengers Bangalore
# 44720              Delhi Daredevils               Mumbai Indians
# 105544  Royal Challengers Bangalore          Chennai Super Kings
# 11032   Royal Challengers Bangalore             Delhi Daredevils
#
#                  city  target       crr        rrr  wickets_left  balls_left  \
# 22755       Cape Town     140  4.800000   7.200000             9         110
# ...

# %% [markdown]
# ## Replacing string data with numerical using OneHotEncoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

col_trf = ColumnTransformer([
    ('col_trf',OneHotEncoder(sparse=False,drop='first'), ['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %% [markdown]
# ## Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
model_pipe = Pipeline(steps=[
    ('step1',col_trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
model_pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=model_pipe.predict(X_test)

# %% [markdown]
# ## accuracy

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Y_test, y_pred)
# Out:
# 0.8064335272268555

# %% [markdown]
# # Probability

# %%
model_pipe.predict_proba(X_test)[10]
# Out:
# array([0.54434444, 0.45565556])

# %%
print("Winning % of team batting 2nd is",int(100*model_pipe.predict_proba(X_test)[10][0]),"%.")
# Out:
# Winning % of team batting 2nd is 54 %.
